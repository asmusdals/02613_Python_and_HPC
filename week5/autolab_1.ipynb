# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1 
para = 100
seq = 20
total = para + seq
F = para / total
print(F)
# Out:
# 0.8333333333333334

# %%
# 2 
p = 10
theoretical_speedup = 1 / ((1-F) + F/p)
print(theoretical_speedup)
# Out:
# 4.000000000000001

# %%
# 3 
theoretical_max = 1 / (1-F)
print(theoretical_max)
# Out:
# 6.000000000000002

# %%
# 4 
p = 4

option_1 = para/p + 5 

p2 = 8 
option_2 = para/p2 + 20

print(f"Option 1: {option_1}")
print(f"Option 2: {option_2}")
# Out:
# Option 1: 30.0
# Option 2: 32.5
